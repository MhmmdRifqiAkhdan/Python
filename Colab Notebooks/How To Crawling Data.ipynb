# %%
import tweepy
import configparser
import pandas as pd

# %%
access_token = "1294969298364948483-ThOEAvrgg3zB3yXoiEe9Ta6vsSgxxO"
access_token_secret = "CswV9kiXRhJEz41giimhsx2P0N8XWAGwwg4w5qpn5DwsK"
api_key = "rhgdf57CxrUB0TqUTjJUadqFf"
api_key_secret = "A4jCEvVJUCyvwd10aB6DGAjDlxaXvH6dc7AHW1CIAnvi4ozD2O"

# %%
auth = tweepy.OAuthHandler(api_key,api_key_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
search_key = "kanjuruhan"

# %%
tweets = tweepy.Cursor(api.search, q=search_key, count=200, tweet_mode="extended").items()

# %%
columns = ['Time', 'User', 'Tweet']
data = []

# %%
for tweet in tweets :
  data.append([tweet.created_at, tweet.id, tweet.user.name, tweet.full_text])

# %%
df = pd.DataFrame(data, columns=columns)
print(df)
