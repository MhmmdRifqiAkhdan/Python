# %%
import pandas as pd 
from google.colab import files
filenya = files.upload()
# Out:
#      <input type="file" id="files-ce5b88a9-f488-4897-9b72-16c6e1d2b4a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce5b88a9-f488-4897-9b72-16c6e1d2b4a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 21.7. Jumlah Tenaga Kerja Menurut Jenis Komoditi Industri Unggulan di Kab Cirebon.csv to 21.7. Jumlah Tenaga Kerja Menurut Jenis Komoditi Industri Unggulan di Kab Cirebon (1).csv

# %%
filenya
# Out:
# {'21.7. Jumlah Tenaga Kerja Menurut Jenis Komoditi Industri Unggulan di Kab Cirebon.csv': b'kode_provinsi,nama_provinsi,kode_kabupaten_kota,nama_kabupaten_kota,unit_usaha,jumlah_tenaga_kerja,satuan,tahun\r\n32,JAWA BARAT,3209,KABUPATEN CIREBON,MEUBEUL/ KERAJINAN ROTAN,63768,ORANG,2021\r\n32,JAWA BARAT,3209,KABUPATEN CIREBON,MEUBEUL KAYU,11986,ORANG,2021\r\n32,JAWA BARAT,3209,KABUPATEN CIREBON,EMPING MELINJO,1377,ORANG,2021\r\n32,JAWA BARAT,3209,KABUPATEN CIREBON,ROTI DAN MAKANAN RINGAN,12266,ORANG,2021\r\n32,JAWA BARAT,3209,KABUPATEN CIREBON,BATU ALAM,1982,ORANG,2021\r\n32,JAWA BARAT,3209,KABUPATEN CIREBON,SANDAL KARET,315,ORANG,2021\r\n32,JAWA BARAT,3209,KABUPATEN CIREBON,BATIK,4688,ORANG,2021\r\n32,JAWA BARAT,3209,KABUPATEN CIREBON,KONVEKSI,13733,ORANG,2021\r\n32,JAWA BARAT,3209,KABUPATEN CIREBON,KERAJINAN KULIT KERANG,780,ORANG,2021\r\n32,JAWA BARAT,3209,KABUPATEN CIREBON,MEUBEUL/ KERAJINAN ROTAN,62826,ORANG,2020\r\n32,JAWA BARAT,3209,KABUPATEN CIREBON,MEUBEUL KAYU,11809,ORANG,202
# ...

# %%
import io 
df = pd.read_csv(io.StringIO(filenya['21.7. Jumlah Tenaga Kerja Menurut Jenis Komoditi Industri Unggulan di Kab Cirebon.csv'].decode('utf-8')))
print(df)
# Out:
#     kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0              32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 1              32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 2              32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 3              32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 4              32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 5              32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 6              32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 7              32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 8              32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 9              32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 10             32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 11             32    JAWA BARAT                 3209   KABUPATEN CIREBON
# ...

# %%
df.head()
# Out:
#    kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0             32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 1             32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 2             32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 3             32    JAWA BARAT                 3209   KABUPATEN CIREBON
# 4             32    JAWA BARAT                 3209   KABUPATEN CIREBON
#
#                  unit_usaha  jumlah_tenaga_kerja satuan  tahun
# 0  MEUBEUL/ KERAJINAN ROTAN                63768  ORANG   2021
# 1              MEUBEUL KAYU                11986  ORANG   2021
# 2            EMPING MELINJO                 1377  ORANG   2021
# 3   ROTI DAN MAKANAN RINGAN                12266  ORANG   2021
# 4                 BATU ALAM                 1982  ORANG   2021
